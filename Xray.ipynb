# %% [markdown]
# <a href="https://colab.research.google.com/github/BIGMEHD/Xray-CNN/blob/G-Colab/Xray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle matplotlib scikit-learn
# !pip install -q tensorflow

# %%
from google.colab import files

# آپلود فایل kaggle.json
uploaded = files.upload()  # بعدش فایل kaggle.json رو انتخاب کن

# انتقال فایل به مسیر درست
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-409e93e7-59f1-4e3d-96d3-139c8e1b6ba8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-409e93e7-59f1-4e3d-96d3-139c8e1b6ba8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# دانلود از Kaggle
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia

# اکسترکت
# !unzip -q chest-xray-pneumonia.zip -d /content/
# !ls -la /content/chest_xray
# Out:
# Dataset URL: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# License(s): other
# ...
# 100% 2.29G/2.29G [00:13<00:00, 241MB/s]
# 100% 2.29G/2.29G [00:13<00:00, 188MB/s]
# total 28
# drwxr-xr-x 7 root root 4096 Aug 28 16:14 .
# drwxr-xr-x 1 root root 4096 Aug 28 16:14 ..
# drwxr-xr-x 5 root root 4096 Aug 28 16:14 chest_xray
# drwxr-xr-x 3 root root 4096 Aug 28 16:14 __MACOSX
# drwxr-xr-x 4 root root 4096 Aug 28 16:14 test
# drwxr-xr-x 4 root root 4096 Aug 28 16:14 train
# drwxr-xr-x 4 root root 4096 Aug 28 16:14 val

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt
import os

# مسیرها (مطابقت با دیتاست دانلودشده)
train_dir = "/content/chest_xray/train"
test_dir  = "/content/chest_xray/test"

# پارامترها
IMG_SIZE = (128, 128)
BATCH_SIZE = 32
EPOCHS = 10  # اگه میخوای بیشتر کن

# ImageDataGenerator برای افزایش داده و نرمال‌سازی
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='binary'
)
test_gen = test_datagen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='binary', shuffle=False
)

# مدل ساده CNN
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# کال‌ بک‌ها و مسیر ذخیره
os.makedirs("outputs", exist_ok=True)
callbacks = [
    EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True),
    ModelCheckpoint("outputs/best_model.h5", monitor='val_loss', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2)
]

# آموزش
history = model.fit(
    train_gen,
    epochs=EPOCHS,
    validation_data=test_gen,
    callbacks=callbacks
)

# ذخیره نهایی
model.save("outputs/final_model.h5")

# رسم نمودارها
plt.figure(figsize=(8,4))
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend(); plt.title('Accuracy')
plt.show()

plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(); plt.title('Loss')
plt.show()
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ...

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# پیش‌بینی روی کل مجموعه تست
y_true = test_gen.classes
test_gen.reset()
preds = model.predict(test_gen, verbose=1)
y_pred = (preds.ravel() > 0.5).astype(int)

# گزارش
print(classification_report(y_true, y_pred, target_names=list(test_gen.class_indices.keys())))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=list(test_gen.class_indices.keys()), yticklabels=list(test_gen.class_indices.keys()))
plt.xlabel("Predicted"); plt.ylabel("True"); plt.title("Confusion Matrix")
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step
#               precision    recall  f1-score   support
#
#       NORMAL       0.86      0.58      0.69       234
#    PNEUMONIA       0.79      0.94      0.86       390
#
#     accuracy                           0.81       624
#    macro avg       0.82      0.76      0.78       624
# weighted avg       0.81      0.81      0.80       624

# %%
from google.colab import drive
drive.mount('/content/drive')
# سپس کپی کن:
# !cp outputs/final_model.h5 /content/drive/MyDrive/xray_final_model.h5
# Out:
# Mounted at /content/drive
